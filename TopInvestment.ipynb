# %% [markdown]
# ## The best companies to invest in with PER<30, EPS>0, consistent dividends and have their year of creation after 2005.

# %% [markdown]
# ### Scrapping the largest companies in the world in market value with PER<25 and EPS>2

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By 

chrome_driver_path = 'C:/Users/sjroo/chromedriver.exe'
options = webdriver.ChromeOptions()
options.add_argument('--start-maximized')
options.add_argument('--disable-extensions')
options.add_argument("--enable-javascript")
service = Service(chrome_driver_path)

driver = webdriver.Chrome(service=service, options=options)
driver.get('https://marketchameleon.com/Screeners/Stocks')

all_dfs = []  # To store all DataFrames from different pages

try:
    button = driver.find_element(By.ID, 'eq_scr_valprofit')
    button.click()

    driver.execute_script("document.querySelector('select[name=c101]').value = 'Below 25.0'")
    driver.execute_script("document.querySelector('select[name=c102]').value = 'Above 2.0'")

    for page_number in range(1, 20):  
        table_div = driver.find_element(By.CLASS_NAME, 'dataTables_scroll')
        table_content = table_div.get_attribute('outerHTML')  # Retrieve the HTML content
        soup = BeautifulSoup(table_content, 'html.parser')
        headers = [th.get_text(strip=True) for th in soup.find('tr').find_all('th')]

        rows = []
        for tr in soup.find_all('tr')[1:]:
            row = [td.get_text(strip=True) for td in tr.find_all('td')]
            rows.append(row)

        df = pd.DataFrame(rows, columns=headers)
        all_dfs.append(df)  # Append each DataFrame to the list

        print(f"Table data for page {page_number}:")
        print(df)
        print("---------------")

        if page_number != 5:
            driver.execute_script(f"document.querySelector(\"a[data-dt-idx='{page_number + 1}']\").click()")
            time.sleep(5)  

except Exception as e:
    print("Error:", e)

finally:
    driver.quit()

final_df = pd.concat(all_dfs, ignore_index=True)
print("Final DataFrame:")
print(final_df)
# Out:
# Table data for page 1:
#    Symbol                                             Name      Price  % Chg  \
# 0    None                                             None       None   None
# 1    None                                             None       None   None
# 2    None                                             None       None   None
# 3    MSFT                                        Microsoft     398.67  +1.2%
# 4    AAPL                                            Apple     191.56  +1.6%
# 5    GOOG                 Alphabet - Class C Capital Stock     147.97  +2.1%
# 6   GOOGL                               Alphabet - Class A     146.38  +2.0%
# 7    AMZN                                       Amazon.com     155.34  +1.2%
# 8    NVDA                                           Nvidia     594.91  +4.2%
# 9    META                         Meta Platforms - Class A     383.45  +2.0%
# 10  BRK.A                               Berkshire Hathaway  556710.00  +1.3%
# 11  BRK.B                           Berkshire Hathaway New     366.99  +1.3%
# 12   TSLA                                            Tesla     212.19  +0.2%
# 13   AVGO                                         Broadcom    1211.20  +5.9%
# 14    LLY                            Eli Lilly And Company     628.58  +0.8%
# 15    TSM  Taiwan Semiconductor Manufacturing Company Ltd.     114.20  +1.0%
# 16      V                                             Visa     270.90  +1.0%
# 17    JPM                                   JPMorgan Chase     170.31  +1.7%
# 18    SPY                           SPDR S&P 500 ETF Trust     482.43  +1.3%
# 19    NVO                                 Novo Nordisk A/S     106.96  -0.5%
# 20    UNH                   Unitedhealth Group Common (De)     503.56  -2.5%
# 21    WMT                                          Walmart     162.38  -0.5%
# 22    IVV                         iShares Core S&P 500 ETF     484.68  +1.3%
# 23     MA                                       Mastercard     436.78  +1.4%
# 24    JNJ                                Johnson & Johnson     161.68  +0.3%
# 25    XOM                                      Exxon Mobil      96.95  +0.2%
# 26    VOO                             Vanguard S&P 500 ETF     443.29  +1.2%
# 27     HD                                       Home Depot     362.41  +1.3%
#
#         Volume  Avg. Volume RelativeVolume Market Cap DividendYield P/E Ratio  \
# 0         None         None           None       None          None      None
# 1         None         None           None       None          None      None
# 2         None         None           None       None          None      None
# 3   24.553.201   24.245.079            1.0      3.0 T         0.75%     38.17
# 4   59.812.232   54.009.439            1.1      3.0 T         0.50%     30.77
# 5   24.333.214   20.387.118            1.2      1.9 T                   27.78
# 6   28.967.183   26.636.712            1.1      1.8 T                   27.49
# 7   41.117.018   49.395.630            0.8      1.6 T                   80.37
# 8   50.164.302   40.605.659            1.2      1.5 T         0.03%     75.34
# 9   17.022.901   17.878.323            1.0    985.4 B                   33.20
# 10        8759         8195            1.1    807.1 B                    8.94
# 11   3.619.667    3.199.492            1.1    798.1 B                    8.84
# 12  96.914.755  112.804.326            0.9    674.5 B                   68.35
# 13   4.624.471    2.802.938            1.6    631.7 B         1.73%     34.69
# 14   2.731.995    3.008.614            0.9    596.7 B         0.83%    112.93
# 15  32.598.100    9.037.353            3.6    592.2 B         1.63%     22.07
# 16   6.103.404    5.638.452            1.1    556.3 B         0.69%     32.38
# 17  10.569.753    9.325.453            1.1    489.9 B         2.47%     10.32
# 18  72.288.509   81.985.995            0.9    484.1 B         1.38%
# 19   3.446.232    4.171.560            0.8    476.8 B         0.97%     44.08
# 20   5.694.442    2.898.135            2.0    465.8 B         1.49%     21.64
# 21   5.908.461    6.761.205            0.9    437.3 B         1.40%     27.16
# 22   4.757.815    5.054.967            0.9    413.7 B         1.59%
# 23   2.187.747    2.429.008            0.9    409.6 B         0.60%     37.55
# 24   6.059.786    6.449.810            0.9    389.3 B         2.94%     30.25
# 25  16.769.571   20.178.924            0.8    388.4 B         3.92%      9.61
# 26   4.638.798    4.686.399            1.0    383.1 B         1.43%
# 27   2.688.360    3.150.923            0.9    360.7 B         2.31%     22.94
#
#                                   Moving AvgIndicator 1 Day Support/Resistance
# 0                                                None                     None
# 1                                                None                     None
# 2                                                None                     None
# 3   UptrendWhen the stock price and moving average...         Above Resistance
# 4                                                             Above Resistance
# 5   UptrendWhen the stock price and moving average...         Above Resistance
# 6   UptrendWhen the stock price and moving average...         Above Resistance
# 7   UptrendWhen the stock price and moving average...
# 8   UptrendWhen the stock price and moving average...         Above Resistance
# 9   UptrendWhen the stock price and moving average...         Above Resistance
# 10  UptrendWhen the stock price and moving average...         Above Resistance
# 11  UptrendWhen the stock price and moving average...         Above Resistance
# 12  Fast Bearish CrossoverWhen the moving averages...
# 13  UptrendWhen the stock price and moving average...         Above Resistance
# 14  UptrendWhen the stock price and moving average...
# 15  UptrendWhen the stock price and moving average...
# 16  UptrendWhen the stock price and moving average...         Above Resistance
# 17  UptrendWhen the stock price and moving average...         Above Resistance
# 18  UptrendWhen the stock price and moving average...         Above Resistance
# 19  UptrendWhen the stock price and moving average...
# 20  Bearish CrossoverWhen the stock has been on an...            Below Support
# 21  UptrendWhen the stock price and moving average...
# 22  UptrendWhen the stock price and moving average...         Above Resistance
# 23  UptrendWhen the stock price and moving average...         Above Resistance
# 24  Bullish CrossoverWhen the stock has been on a ...
# 25  DowntrendWhen the stock price and moving avera...
# 26  UptrendWhen the stock price and moving average...         Above Resistance
# 27  UptrendWhen the stock price and moving average...         Above Resistance
# ---------------
# Table data for page 2:
#    Symbol                                             Name   Price  % Chg  \
# 0    None                                             None    None   None
# 1    None                                             None    None   None
# 2    None                                             None    None   None
# 3     VTI                  Vanguard Total Stock Market ETF  239.54  +1.2%
# 4      PG                         Procter & Gamble Company  147.57  -0.4%
# 5    COST                                 Costco Wholesale  694.97  +1.1%
# 6    ORCL                                           Oracle  109.67  +0.9%
# 7     MRK                               Merck Common (New)  118.89  +0.3%
# 8    ASML     Asml Holding N.V. - New York Registry Shares  757.83  +1.8%
# 9    ABBV                                           Abbvie  164.77  +0.9%
# 10    CRM                                       Salesforce  280.88  +2.3%
# 11    AMD                           Advanced Micro Devices  174.23  +7.1%
# 12   ADBE                                            Adobe  611.55  +3.0%
# 13     TM                                     Toyota Motor  200.67  +0.3%
# 14    CVX                                          Chevron  142.24  +0.3%
# 15     KO                                Coca-Cola Company   59.83  -0.5%
# 16    BAC                                  Bank Of America   32.22  +1.5%
# 17    QQQ                                Invesco QQQ Trust  421.18  +2.0%
# 18    FMX        Fomento Economico Mexicano S.A.B. De C.V.  133.65  +0.9%
# 19    ACN  Accenture PLC Class A Ordinary Shares (Ireland)  363.90  +1.2%
# 20    PEP                                          Pepsico  165.78  -0.8%
# 21    NVS                                      Novartis Ag  108.23  +0.2%
# 22    MCD                                       McDonald's  300.53  +2.1%
# 23    TMO                         Thermo Fisher Scientific  551.75  +1.4%
# 24   NFLX                                          Netflix  482.95  -0.5%
# 25   CSCO                                    Cisco Systems   51.27  +1.0%
# 26    AZN     Astrazeneca PLC - American Depositary Shares   66.54  +0.0%
# 27   INTC                                            Intel   48.15  +3.0%
#
#          Volume Avg. Volume RelativeVolume Market Cap DividendYield P/E Ratio  \
# 0          None        None           None       None          None      None
# 1          None        None           None       None          None      None
# 2          None        None           None       None          None      None
# 3     3.774.848   3.371.998            1.1    352.6 B         1.42%
# 4     7.053.686   6.359.939            1.1    348.1 B         2.55%     24.05
# 5     2.009.047   1.927.796            1.0    308.4 B         0.59%     46.85
# 6     7.963.457   9.802.987            0.8    301.5 B         1.46%     30.03
# 7     6.586.425   7.500.486            0.9    301.3 B         2.59%     65.86
# 8     1.520.167     942.821            1.6    299.0 B         0.77%     35.42
# 9     4.874.233   4.975.697            1.0    290.7 B         3.76%     44.74
# 10    6.100.745   4.874.515            1.3    280.9 B                  104.36
# 11  132.900.824  55.542.318            2.4    280.8 B                 1478.82
# 12    3.364.796   2.760.939            1.2    276.4 B                   50.23
# 13      280.220     304.498            0.9    270.8 B                   10.39
# 14    9.768.944   9.615.959            1.0    267.7 B         4.25%     10.53
# 15   12.037.932  14.642.655            0.8    258.8 B         3.08%     24.36
# 16   43.565.662  43.481.650            1.0    254.4 B         2.98%     10.30
# 17   48.581.490  48.573.862            1.0    239.8 B         0.50%
# 18      527.347     534.925            1.0    239.1 B         1.56%     33.38
# 19    2.317.834   1.957.253            1.2    228.2 B         1.42%     33.32
# 20    5.469.439   5.229.704            1.0    227.9 B         3.05%     27.86
# 21    1.179.632   1.469.566            0.8    222.5 B         3.21%     27.99
# 22    3.914.626   2.886.925            1.4    219.8 B         2.22%     25.96
# 23    1.844.639   1.761.279            1.0    212.7 B         0.25%     35.68
# 24    4.834.168   4.754.957            1.0    211.4 B                   48.43
# 25   18.951.041  17.848.297            1.1    208.3 B         3.04%     15.33
# 26    6.190.443   5.278.691            1.2    206.2 B         2.13%     35.20
# 27   50.318.282  36.730.482            1.4    203.0 B         1.04%
#
#                                   Moving AvgIndicator 1 Day Support/Resistance
# 0                                                None                     None
# 1                                                None                     None
# 2                                                None                     None
# 3   UptrendWhen the stock price and moving average...         Above Resistance
# 4
# 5   UptrendWhen the stock price and moving average...         Above Resistance
# 6
# 7   Bullish CrossoverWhen the stock has been on a ...
# 8   UptrendWhen the stock price and moving average...         Above Resistance
# 9   UptrendWhen the stock price and moving average...
# 10  UptrendWhen the stock price and moving average...         Above Resistance
# 11  UptrendWhen the stock price and moving average...         Above Resistance
# 12                                                            Above Resistance
# 13
# 14  Dead Cat BounceWhen the stock has been on a do...
# 15  Bullish CrossoverWhen the stock has been on a ...
# 16  Top PullbackWhen the stock is in an uptrend bu...         Above Resistance
# 17  UptrendWhen the stock price and moving average...         Above Resistance
# 18  UptrendWhen the stock price and moving average...
# 19  UptrendWhen the stock price and moving average...         Above Resistance
# 20
# 21  UptrendWhen the stock price and moving average...
# 22  UptrendWhen the stock price and moving average...         Above Resistance
# 23  Bullish CrossoverWhen the stock has been on a ...
# 24  Top PullbackWhen the stock is in an uptrend bu...
# 25                                                            Above Resistance
# 26
# 27  UptrendWhen the stock price and moving average...         Above Resistance
# ---------------
# Table data for page 3:
#    Symbol                                               Name   Price  % Chg  \
# 0    None                                               None    None   None
# 1    None                                               None    None   None
# 2    None                                               None    None   None
# 3     ABT                                Abbott Laboratories  114.69  +0.6%
# 4    SHEL  Shell PLC American Depositary Shares (Each Rep...   61.11  -0.4%
# 5     LIN                                        Linde PLC -  407.38  -0.1%
# 6     SAP                                        Sap  Se Ads  163.45  +1.9%
# 7    TMUS                                        T-Mobile US  165.16  +0.2%
# 8     PDD          PDD Holdings - American Depositary Shares  143.64  +1.1%
# 9   CMCSA                                  Comcast - Class A   43.35  +1.9%
# 10   INTU                                             Intuit  622.18  +1.8%
# 11   BABA                                 Alibaba Gr Holding   69.42  +2.0%
# 12    WFC                                        Wells Fargo   48.12  +3.6%
# 13    DHR                                            Danaher  231.05  +2.1%
# 14    DIS                                Walt Disney Company   93.06  +0.9%
# 15   QCOM                                           Qualcomm  151.96  +4.6%
# 16     VZ                             Verizon Communications   39.33  +1.0%
# 17   AMGN                                              Amgen  307.81  +1.1%
# 18    PFE                                             Pfizer   28.28  +0.7%
# 19    TXN                                  Texas Instruments  173.65  +4.0%
# 20    IBM                    International Business Machines  171.48  +2.8%
# 21    NKE                                               Nike  101.78  +0.8%
# 22    NOW                                         Servicenow  749.11  +0.4%
# 23    BHP  BHP Group Limited American Depositary Shares (...   60.53  +0.1%
# 24    CAT                                        Caterpillar  285.28  +1.7%
# 25    TTE                                   Totalenergies Se   63.86  -0.2%
# 26    UNP                                      Union Pacific  239.27  +0.5%
# 27   HSBC                                 HSBC Holdings Plc.   37.99  +0.3%
#
#         Volume Avg. Volume RelativeVolume Market Cap DividendYield P/E Ratio  \
# 0         None        None           None       None          None      None
# 1         None        None           None       None          None      None
# 2         None        None           None       None          None      None
# 3    6.317.298   5.343.709            1.2    199.3 B         1.92%     38.75
# 4    3.489.846   5.397.953            0.6    198.7 B         2.49%      7.29
# 5    1.940.151   1.496.815            1.3    197.5 B         1.25%     33.73
# 6      724.869     800.546            0.9    191.2 B         1.34%     80.54
# 7    3.604.972   4.333.597            0.8    191.0 B         0.39%     25.60
# 8    4.959.476   7.507.945            0.7    180.0 B                   32.09
# 9   20.970.707  17.745.338            1.2    174.5 B         2.68%     11.85
# 10   1.079.535   1.312.681            0.8    174.2 B         0.58%     66.96
# 11  31.902.898  16.013.734            2.0    173.5 B         0.18%      9.57
# 12  23.857.230  16.317.909            1.5    173.2 B         2.91%      9.61
# 13   3.054.605   2.885.858            1.1    170.7 B         0.42%     28.54
# 14  13.200.333  12.533.177            1.1    170.3 B         0.32%     71.48
# 15  14.398.064   7.817.418            1.8    169.4 B         2.11%     22.28
# 16  19.173.114  21.257.892            0.9    165.3 B         6.76%      7.84
# 17   2.293.503   2.408.169            1.0    164.6 B         2.92%     21.66
# 18  29.381.081  35.819.247            0.8    159.6 B         5.94%     15.35
# 19  11.446.359   5.030.909            2.3    157.6 B         2.99%     21.62
# 20   6.452.334   3.974.831            1.6    156.2 B         3.87%     21.53
# 21   7.942.891   8.794.216            0.9    154.9 B         1.45%     29.43
# 22   1.206.643   1.075.364            1.1    153.6 B                   96.38
# 23   2.366.817   2.285.877            1.0    153.2 B         2.64%     11.86
# 24   2.587.912   2.753.749            0.9    152.2 B         1.82%     15.98
# 25   1.441.989   1.264.347            1.1    149.9 B         4.88%      8.15
# 26   1.901.897   2.329.510            0.8    145.9 B         2.17%     22.84
# 27   2.191.018   1.990.249            1.1    145.6 B         6.98%      5.49
#
#                                   Moving AvgIndicator 1 Day Support/Resistance
# 0                                                None                     None
# 1                                                None                     None
# 2                                                None                     None
# 3   UptrendWhen the stock price and moving average...
# 4
# 5
# 6   UptrendWhen the stock price and moving average...         Above Resistance
# 7   UptrendWhen the stock price and moving average...
# 8   Top PullbackWhen the stock is in an uptrend bu...
# 9   Top PullbackWhen the stock is in an uptrend bu...         Above Resistance
# 10  UptrendWhen the stock price and moving average...         Above Resistance
# 11  DowntrendWhen the stock price and moving avera...
# 12  Top PullbackWhen the stock is in an uptrend bu...         Above Resistance
# 13  Bullish CrossoverWhen the stock has been on a ...         Above Resistance
# 14
# 15  UptrendWhen the stock price and moving average...         Above Resistance
# 16  UptrendWhen the stock price and moving average...
# 17  UptrendWhen the stock price and moving average...
# 18  DowntrendWhen the stock price and moving avera...
# 19  Bullish CrossoverWhen the stock has been on a ...         Above Resistance
# 20  UptrendWhen the stock price and moving average...         Above Resistance
# 21  DowntrendWhen the stock price and moving avera...
# 22  UptrendWhen the stock price and moving average...
# 23  Fast Bearish CrossoverWhen the moving averages...
# 24  Top PullbackWhen the stock is in an uptrend bu...         Above Resistance
# 25
# 26  Top PullbackWhen the stock is in an uptrend bu...
# 27  Fast Bearish CrossoverWhen the moving averages...
# ---------------
# Table data for page 4:
#    Symbol                                             Name    Price  % Chg  \
# 0    None                                             None     None   None
# 1    None                                             None     None   None
# 2    None                                             None     None   None
# 3      PM                               Philip Morris Intl    92.32  -0.9%
# 4      GE                         General Electric Company   129.81  +1.0%
# 5     HDB                                        HDFC Bank    55.84  -1.2%
# 6    SPGI                                       S&P Global   441.95  +0.5%
# 7      MS                                   Morgan Stanley    85.34  +1.7%
# 8    AMAT                                Applied Materials   167.94  +4.7%
# 9      RY                             Royal Bank Of Canada    99.62  +1.5%
# 10    UPS                            United Parcel Service   156.89  +0.2%
# 11   BKNG                                 Booking Holdings  3616.51  +2.5%
# 12   UBER                                Uber Technologies    65.11  +0.4%
# 13    AXP                         American Express Company   183.17  +1.9%
# 14    HON                                   Honeywell Intl   200.78  +0.3%
# 15   ISRG                               Intuitive Surgical   374.82  +0.8%
# 16    COP                                   Conocophillips   107.87  +0.9%
# 17     BA                                   Boeing Company   215.02  +1.6%
# 18     GS                              Goldman Sachs Group   382.20  +1.4%
# 19    SNY              Sanofi - American Depositary Shares    51.03  -1.6%
# 20    LOW                                 Lowe's Companies   220.01  +0.8%
# 21    BUD  Anheuser-Busch Inbev SA Sponsored ADR (Belgium)    63.01  +0.5%
# 22    RTX                                              RTX    85.53  +0.1%
# 23   SONY            Sony Group American Depositary Shares    99.02  +1.2%
# 24    VEA              Vanguard FTSE Developed Markets ETF    46.78  +0.3%
# 25    BLK                                        Blackrock   805.44  +1.3%
# 26    SYK                                          Stryker   315.05  +0.1%
# 27      T                                             AT&T    16.67  +1.7%
#
#         Volume Avg. Volume RelativeVolume Market Cap DividendYield P/E Ratio  \
# 0         None        None           None       None          None      None
# 1         None        None           None       None          None      None
# 2         None        None           None       None          None      None
# 3    5.483.600   4.351.274            1.3    143.3 B         5.63%     18.10
# 4    4.513.714   4.399.342            1.0    141.4 B         0.25%     13.38
# 5    6.645.384   2.465.794            2.7    141.3 B         1.25%     16.38
# 6      881.348   1.130.186            0.8    140.6 B         0.81%     57.17
# 7   13.685.363   8.417.373            1.6    140.1 B         3.98%     16.20
# 8    8.089.507   5.415.823            1.5    139.6 B         0.76%     19.77
# 9      525.096   1.118.960            0.5    139.0 B         4.11%     12.63
# 10   2.903.493   3.450.746            0.8    134.4 B         4.13%     15.84
# 11     219.846     244.411            0.9    134.2 B                   24.96
# 12  18.638.177  26.031.718            0.7    134.0 B                  124.77
# 13   3.038.223   2.977.518            1.0    133.5 B         1.31%     16.85
# 14   2.621.055   2.733.256            1.0    132.4 B         2.15%     24.80
# 15   1.947.993   1.748.141            1.1    132.0 B                   87.51
# 16   5.329.856   5.352.696            1.0    131.5 B         2.15%     11.65
# 17  12.720.009   6.658.530            1.9    130.0 B
# 18   2.338.190   2.002.120            1.2    128.2 B         2.88%     16.49
# 19   1.637.608   1.823.238            0.9    127.7 B         3.73%     13.20
# 20   2.659.826   2.765.262            1.0    126.5 B         2.00%     16.72
# 21     848.231   1.755.344            0.5    125.0 B         1.31%     20.43
# 22   6.945.202   9.592.338            0.7    123.0 B         2.76%     39.39
# 23     413.780     729.360            0.6    121.9 B                   22.09
# 24   9.747.378  11.358.484            0.9    120.1 B         3.23%
# 25     646.536     638.803            1.0    119.6 B         2.53%     21.78
# 26   1.767.439   1.451.718            1.2    119.4 B         1.02%     46.69
# 27  47.861.342  35.309.109            1.4    119.2 B         6.66%
#
#                                   Moving AvgIndicator 1 Day Support/Resistance
# 0                                                None                     None
# 1                                                None                     None
# 2                                                None                     None
# 3
# 4   UptrendWhen the stock price and moving average...
# 5                                                                Below Support
# 6   UptrendWhen the stock price and moving average...
# 7                                                             Above Resistance
# 8   UptrendWhen the stock price and moving average...         Above Resistance
# 9                                                             Above Resistance
# 10
# 11  UptrendWhen the stock price and moving average...         Above Resistance
# 12  UptrendWhen the stock price and moving average...
# 13  Top PullbackWhen the stock is in an uptrend bu...         Above Resistance
# 14  Top PullbackWhen the stock is in an uptrend bu...
# 15  UptrendWhen the stock price and moving average...
# 16  Fast Bearish CrossoverWhen the moving averages...
# 17  Fast Bearish CrossoverWhen the moving averages...
# 18  Top PullbackWhen the stock is in an uptrend bu...         Above Resistance
# 19  Bullish CrossoverWhen the stock has been on a ...            Below Support
# 20  Bullish CrossoverWhen the stock has been on a ...
# 21  Top PullbackWhen the stock is in an uptrend bu...
# 22  Bullish CrossoverWhen the stock has been on a ...
# 23  UptrendWhen the stock price and moving average...
# 24  Top PullbackWhen the stock is in an uptrend bu...
# 25  UptrendWhen the stock price and moving average...
# 26  UptrendWhen the stock price and moving average...
# 27                                                            Above Resistance
# ---------------
# Table data for page 5:
#    Symbol                                       Name   Price  % Chg  \
# 0    None                                       None    None   None
# 1    None                                       None    None   None
# 2    None                                       None    None   None
# 3     PLD                                   Prologis  128.44  +1.7%
# 4      UL                               Unilever PLC   47.17   0.0%
# 5    SCHW                             Charles Schwab   63.78  +1.7%
# 6     NEE                             Nextera Energy   57.26  -0.7%
# 7     MDT                             Medtronic Plc.   86.49  +0.2%
# 8     LMT                            Lockheed Martin  457.76  -0.4%
# 9    VRTX                     Vertex Pharmaceuticals  435.02  +0.5%
# 10    RIO                              Rio Tinto PLC   68.75  -0.6%
# 11     TD                      Toronto-Dominion Bank   60.42  +1.7%
# 12    TJX                              TJX Companies   95.50  +0.8%
# 13    ELV                            Elevance Health  464.61  -1.0%
# 14   LRCX                               Lam Research  826.32  +5.2%
# 15   GILD                            Gilead Sciences   87.29  +1.0%
# 16    VUG                        Vanguard Growth ETF  319.98  +1.5%
# 17     DE                                      Deere  382.72  +0.4%
# 18   SBUX                                  Starbucks   93.86  +0.6%
# 19   PANW                         Palo Alto Networks  337.74  +0.6%
# 20    VTV                         Vanguard Value ETF  149.20  +0.9%
# 21   MUFG                     Mitsubishi Ufj Finl Gr    8.84  +0.3%
# 22   IEFA                 iShares Core MSCI Eafe ETF   68.89  +0.2%
# 23    BND             Vanguard Total Bond Market ETF   72.67   0.0%
# 24   REGN                  Regeneron Pharmaceuticals  933.40  +0.4%
# 25   SHOP  Shopify Class A Subordinate Voting Shares   80.01  +3.2%
# 26    PBR                       Petrobras Brasileiro   15.74  -0.5%
# 27    BMY               Bristol-Myers Squibb Company   50.11  +0.0%
#
#         Volume Avg. Volume RelativeVolume Market Cap DividendYield P/E Ratio  \
# 0         None        None           None       None          None      None
# 1         None        None           None       None          None      None
# 2         None        None           None       None          None      None
# 3    3.176.929   3.313.108            1.0    118.6 B         2.71%     40.21
# 4    2.110.142   2.286.688            0.9    118.0 B         3.97%     13.30
# 5   10.402.170   9.842.295            1.1    116.2 B         1.57%     24.69
# 6   11.521.681  13.220.951            0.9    115.9 B         3.27%     15.21
# 7    4.320.327   6.255.269            0.7    115.1 B         3.19%     28.02
# 8      807.771   1.195.633            0.7    113.6 B         2.75%     16.82
# 9    2.303.197   1.244.822            1.9    112.1 B                   32.51
# 10   3.231.430   2.830.545            1.1    111.5 B         5.85%     13.13
# 11   1.695.483   2.955.181            0.6    109.9 B         4.80%     14.33
# 12   3.634.740   4.920.572            0.7    109.3 B         1.39%     26.77
# 13   1.905.333   1.048.642            1.8    109.2 B         1.27%     18.26
# 14   1.758.176     957.877            1.8    108.9 B         0.97%     26.65
# 15   5.834.317   5.878.864            1.0    108.8 B         3.44%     18.50
# 16     871.285     908.330            1.0    107.7 B         0.56%
# 17   1.098.348   1.501.849            0.7    107.3 B         1.54%     11.01
# 18   8.216.759   6.838.272            1.2    106.7 B         2.43%     26.07
# 19   2.655.782   3.553.368            0.7    106.5 B                  188.63
# 20   2.016.083   2.562.572            0.8    105.5 B         2.46%
# 21   3.221.623   3.317.838            1.0    105.3 B                    8.76
# 22   7.027.021   8.423.685            0.8    104.6 B         2.81%
# 23   7.679.773   7.322.836            1.0    104.1 B         3.15%
# 24     664.836     492.946            1.3    102.4 B                   26.53
# 25   9.704.582  10.508.208            0.9    102.1 B
# 26   8.515.200  16.042.219            0.5    102.1 B        11.86%      3.83
# 27  21.672.782  13.654.057            1.6    102.0 B         4.79%     12.71
#
#                                   Moving AvgIndicator 1 Day Support/Resistance
# 0                                                None                     None
# 1                                                None                     None
# 2                                                None                     None
# 3                                                             Above Resistance
# 4
# 5   Top PullbackWhen the stock is in an uptrend bu...
# 6   Dead Cat BounceWhen the stock has been on a do...
# 7   Bullish CrossoverWhen the stock has been on a ...
# 8
# 9   UptrendWhen the stock price and moving average...
# 10  Fast Bearish CrossoverWhen the moving averages...
# 11                                                            Above Resistance
# 12  UptrendWhen the stock price and moving average...
# 13
# 14  UptrendWhen the stock price and moving average...         Above Resistance
# 15  UptrendWhen the stock price and moving average...
# 16  UptrendWhen the stock price and moving average...         Above Resistance
# 17
# 18  DowntrendWhen the stock price and moving avera...
# 19  UptrendWhen the stock price and moving average...
# 20  UptrendWhen the stock price and moving average...         Above Resistance
# 21  UptrendWhen the stock price and moving average...
# 22  Top PullbackWhen the stock is in an uptrend bu...
# 23
# 24  UptrendWhen the stock price and moving average...
# 25  UptrendWhen the stock price and moving average...         Above Resistance
# 26  Top PullbackWhen the stock is in an uptrend bu...
# 27
# ---------------
# Table data for page 6:
#    Symbol                                       Name   Price  % Chg  \
# 0    None                                       None    None   None
# 1    None                                       None    None   None
# 2    None                                       None    None   None
# 3     PLD                                   Prologis  128.44  +1.7%
# 4      UL                               Unilever PLC   47.17   0.0%
# 5    SCHW                             Charles Schwab   63.78  +1.7%
# 6     NEE                             Nextera Energy   57.26  -0.7%
# 7     MDT                             Medtronic Plc.   86.49  +0.2%
# 8     LMT                            Lockheed Martin  457.76  -0.4%
# 9    VRTX                     Vertex Pharmaceuticals  435.02  +0.5%
# 10    RIO                              Rio Tinto PLC   68.75  -0.6%
# 11     TD                      Toronto-Dominion Bank   60.42  +1.7%
# 12    TJX                              TJX Companies   95.50  +0.8%
# 13    ELV                            Elevance Health  464.61  -1.0%
# 14   LRCX                               Lam Research  826.32  +5.2%
# 15   GILD                            Gilead Sciences   87.29  +1.0%
# 16    VUG                        Vanguard Growth ETF  319.98  +1.5%
# 17     DE                                      Deere  382.72  +0.4%
# 18   SBUX                                  Starbucks   93.86  +0.6%
# 19   PANW                         Palo Alto Networks  337.74  +0.6%
# 20    VTV                         Vanguard Value ETF  149.20  +0.9%
# 21   MUFG                     Mitsubishi Ufj Finl Gr    8.84  +0.3%
# 22   IEFA                 iShares Core MSCI Eafe ETF   68.89  +0.2%
# 23    BND             Vanguard Total Bond Market ETF   72.67   0.0%
# 24   REGN                  Regeneron Pharmaceuticals  933.40  +0.4%
# 25   SHOP  Shopify Class A Subordinate Voting Shares   80.01  +3.2%
# 26    PBR                       Petrobras Brasileiro   15.74  -0.5%
# 27    BMY               Bristol-Myers Squibb Company   50.11  +0.0%
#
#         Volume Avg. Volume RelativeVolume Market Cap DividendYield P/E Ratio  \
# 0         None        None           None       None          None      None
# 1         None        None           None       None          None      None
# 2         None        None           None       None          None      None
# 3    3.176.929   3.313.108            1.0    118.6 B         2.71%     40.21
# 4    2.110.142   2.286.688            0.9    118.0 B         3.97%     13.30
# 5   10.402.170   9.842.295            1.1    116.2 B         1.57%     24.69
# 6   11.521.681  13.220.951            0.9    115.9 B         3.27%     15.21
# 7    4.320.327   6.255.269            0.7    115.1 B         3.19%     28.02
# 8      807.771   1.195.633            0.7    113.6 B         2.75%     16.82
# 9    2.303.197   1.244.822            1.9    112.1 B                   32.51
# 10   3.231.430   2.830.545            1.1    111.5 B         5.85%     13.13
# 11   1.695.483   2.955.181            0.6    109.9 B         4.80%     14.33
# 12   3.634.740   4.920.572            0.7    109.3 B         1.39%     26.77
# 13   1.905.333   1.048.642            1.8    109.2 B         1.27%     18.26
# 14   1.758.176     957.877            1.8    108.9 B         0.97%     26.65
# 15   5.834.317   5.878.864            1.0    108.8 B         3.44%     18.50
# 16     871.285     908.330            1.0    107.7 B         0.56%
# 17   1.098.348   1.501.849            0.7    107.3 B         1.54%     11.01
# 18   8.216.759   6.838.272            1.2    106.7 B         2.43%     26.07
# 19   2.655.782   3.553.368            0.7    106.5 B                  188.63
# 20   2.016.083   2.562.572            0.8    105.5 B         2.46%
# 21   3.221.623   3.317.838            1.0    105.3 B                    8.76
# 22   7.027.021   8.423.685            0.8    104.6 B         2.81%
# 23   7.679.773   7.322.836            1.0    104.1 B         3.15%
# 24     664.836     492.946            1.3    102.4 B                   26.53
# 25   9.704.582  10.508.208            0.9    102.1 B
# 26   8.515.200  16.042.219            0.5    102.1 B        11.86%      3.83
# 27  21.672.782  13.654.057            1.6    102.0 B         4.79%     12.71
#
#                                   Moving AvgIndicator 1 Day Support/Resistance
# 0                                                None                     None
# 1                                                None                     None
# 2                                                None                     None
# 3                                                             Above Resistance
# 4
# 5   Top PullbackWhen the stock is in an uptrend bu...
# 6   Dead Cat BounceWhen the stock has been on a do...
# 7   Bullish CrossoverWhen the stock has been on a ...
# 8
# 9   UptrendWhen the stock price and moving average...
# 10  Fast Bearish CrossoverWhen the moving averages...
# 11                                                            Above Resistance
# 12  UptrendWhen the stock price and moving average...
# 13
# 14  UptrendWhen the stock price and moving average...         Above Resistance
# 15  UptrendWhen the stock price and moving average...
# 16  UptrendWhen the stock price and moving average...         Above Resistance
# 17
# 18  DowntrendWhen the stock price and moving avera...
# 19  UptrendWhen the stock price and moving average...
# 20  UptrendWhen the stock price and moving average...         Above Resistance
# 21  UptrendWhen the stock price and moving average...
# 22  Top PullbackWhen the stock is in an uptrend bu...
# 23
# 24  UptrendWhen the stock price and moving average...
# 25  UptrendWhen the stock price and moving average...         Above Resistance
# 26  Top PullbackWhen the stock is in an uptrend bu...
# 27
# ---------------
# Error: Message: javascript error: Cannot read properties of null (reading 'click')
#   (Session info: chrome=120.0.6099.225)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF78EA94D02+56194]
# 	(No symbol) [0x00007FF78EA004B2]
# 	(No symbol) [0x00007FF78E8A76AA]
# 	(No symbol) [0x00007FF78E8ACFC0]
# 	(No symbol) [0x00007FF78E8AF6F7]
# 	(No symbol) [0x00007FF78E932FFB]
# 	(No symbol) [0x00007FF78E915E7A]
# 	(No symbol) [0x00007FF78E932786]
# 	(No symbol) [0x00007FF78E915C23]
# 	(No symbol) [0x00007FF78E8E4A45]
# 	(No symbol) [0x00007FF78E8E5AD4]
# 	GetHandleVerifier [0x00007FF78EE0D5BB+3695675]
# 	GetHandleVerifier [0x00007FF78EE66197+4059159]
# 	GetHandleVerifier [0x00007FF78EE5DF63+4025827]
# 	GetHandleVerifier [0x00007FF78EB2F029+687785]
# 	(No symbol) [0x00007FF78EA0B508]
# 	(No symbol) [0x00007FF78EA07564]
# 	(No symbol) [0x00007FF78EA076E9]
# 	(No symbol) [0x00007FF78E9F8094]
# 	BaseThreadInitThunk [0x00007FFF1C2A7344+20]
# 	RtlUserThreadStart [0x00007FFF1C4826B1+33]
#
# Final DataFrame:
#     Symbol                                       Name   Price  % Chg  \
# 0     None                                       None    None   None
# 1     None                                       None    None   None
# 2     None                                       None    None   None
# 3     MSFT                                  Microsoft  398.67  +1.2%
# 4     AAPL                                      Apple  191.56  +1.6%
# ..     ...                                        ...     ...    ...
# 163    BND             Vanguard Total Bond Market ETF   72.67   0.0%
# 164   REGN                  Regeneron Pharmaceuticals  933.40  +0.4%
# 165   SHOP  Shopify Class A Subordinate Voting Shares   80.01  +3.2%
# 166    PBR                       Petrobras Brasileiro   15.74  -0.5%
# 167    BMY               Bristol-Myers Squibb Company   50.11  +0.0%
#
#          Volume Avg. Volume RelativeVolume Market Cap DividendYield P/E Ratio  \
# 0          None        None           None       None          None      None
# 1          None        None           None       None          None      None
# 2          None        None           None       None          None      None
# 3    24.553.201  24.245.079            1.0      3.0 T         0.75%     38.17
# 4    59.812.232  54.009.439            1.1      3.0 T         0.50%     30.77
# ..          ...         ...            ...        ...           ...       ...
# 163   7.679.773   7.322.836            1.0    104.1 B         3.15%
# 164     664.836     492.946            1.3    102.4 B                   26.53
# 165   9.704.582  10.508.208            0.9    102.1 B
# 166   8.515.200  16.042.219            0.5    102.1 B        11.86%      3.83
# 167  21.672.782  13.654.057            1.6    102.0 B         4.79%     12.71
#
#                                    Moving AvgIndicator  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    UptrendWhen the stock price and moving average...
# 4
# ..                                                 ...
# 163
# 164  UptrendWhen the stock price and moving average...
# 165  UptrendWhen the stock price and moving average...
# 166  Top PullbackWhen the stock is in an uptrend bu...
# 167
#
#     1 Day Support/Resistance
# 0                       None
# 1                       None
# 2                       None
# 3           Above Resistance
# 4           Above Resistance
# ..                       ...
# 163
# 164
# 165         Above Resistance
# 166
# 167
#
# [168 rows x 12 columns]

# %%
import json

final_df.to_json('stock_data.json', orient='records')

# %%
columns_to_drop = ['% Chg', 'Avg. Volume', 'RelativeVolume', 'Moving AvgIndicator', '1 Day Support/Resistance']

final_df.drop(columns=columns_to_drop, inplace=True)

final_df
# Out:
#     Symbol                                       Name   Price      Volume  \
# 0     None                                       None    None        None
# 1     None                                       None    None        None
# 2     None                                       None    None        None
# 3     MSFT                                  Microsoft  398.67  24.553.201
# 4     AAPL                                      Apple  191.56  59.812.232
# ..     ...                                        ...     ...         ...
# 163    BND             Vanguard Total Bond Market ETF   72.67   7.679.773
# 164   REGN                  Regeneron Pharmaceuticals  933.40     664.836
# 165   SHOP  Shopify Class A Subordinate Voting Shares   80.01   9.704.582
# 166    PBR                       Petrobras Brasileiro   15.74   8.515.200
# 167    BMY               Bristol-Myers Squibb Company   50.11  21.672.782
#
#     Market Cap DividendYield P/E Ratio
# 0         None          None      None
# 1         None          None      None
# 2         None          None      None
# 3        3.0 T         0.75%     38.17
# 4        3.0 T         0.50%     30.77
# ..         ...           ...       ...
# 163    104.1 B         3.15%
# 164    102.4 B                   26.53
# 165    102.1 B
# 166    102.1 B        11.86%      3.83
# 167    102.0 B         4.79%     12.71
#
# [168 rows x 7 columns]

# %%
final_df.dropna(how='all', inplace=True)

final_df.shape
# Out:
# (150, 7)

# %%
final_df['Name'].to_csv('stocks.txt', sep=' ', index=False)

# %% [markdown]
# ## Year of foundation of the extracted companies.

# %%
ruta_archivo = 'C:/Users/sjroo/añofundación.txt'

stock_found = pd.read_csv(ruta_archivo, sep='\t')

stock_found
# Out:
#                                             Name
# 0                                   Apple (1976)
# 1                               Microsoft (1975)
# 2        Alphabet - Class C Capital Stock (2015)
# 3                      Alphabet - Class A (2015)
# 4                              Amazon.com (1994)
# ..                                           ...
# 120                          Lam Research (1980)
# 121                            CVS Health (1963)
# 122  iShares Core U.S. Aggregate Bond ETF (2003)
# 123                             BP P.L.C. (1909)
# 124                       Gilead Sciences (1987)
#
# [125 rows x 1 columns]

# %%
import re

stock_found['Year'] = stock_found['Name'].str.extract(r'\((\d{4})\)', expand=False)

stock_found['Name'] = stock_found['Name'].str.replace(r'\s*\(\d{4}\)', '')

stock_found['Name'] = stock_found['Name'].str.replace(r'\s*\(\d{4}\)', '', regex=True)


print(stock_found)
# Out:
#                                      Name  Year
# 0                                   Apple  1976
# 1                               Microsoft  1975
# 2        Alphabet - Class C Capital Stock  2015
# 3                      Alphabet - Class A  2015
# 4                              Amazon.com  1994
# ..                                    ...   ...
# 120                          Lam Research  1980
# 121                            CVS Health  1963
# 122  iShares Core U.S. Aggregate Bond ETF  2003
# 123                             BP P.L.C.  1909
# 124                       Gilead Sciences  1987
#
# [125 rows x 2 columns]

# %% [markdown]
# ### Creating a database in SQL to manipulate the two tables

# %%
from sqlalchemy import create_engine
from sqlalchemy import inspect

engine = create_engine(f'mysql+mysqlconnector://root:Gffp13102109@127.0.0.1/stocks')

final_df.to_sql('stock_data', con=engine, if_exists='replace', index=False)
stock_found.to_sql('found_year', con=engine, if_exists='replace', index=False)

inspector = inspect(engine)

print(inspector.get_table_names())
# Out:
# ['best_investment', 'found_year', 'stock_data']

# %% [markdown]
# ## Table with years of foundation of the largest companies in the market

# %%
query = f"SELECT * FROM best_investment"

# Read the table data into a DataFrame
best_investment = pd.read_sql(query, engine)

# Display the DataFrame
print(best_investment)
# Out:
#    Symbol                                             Name   Price     Volume  \
# 0    GOOG                 Alphabet - Class C Capital Stock  140.75  3.162.040
# 1   GOOGL                               Alphabet - Class A  139.65  3.411.497
# 2     VOO                             Vanguard S&P 500 ETF  437.06    810.726
# 3    ABBV                                           Abbvie  155.05    437.883
# 4     TMO                         Thermo Fisher Scientific  532.59    126.537
# 5     PDD        PDD Holdings - American Depositary Shares  145.95  1.068.642
# 6     BUD  Anheuser-Busch Inbev SA Sponsored ADR (Belgium)   64.66    220.747
# 7    UBER                                Uber Technologies   62.00  5.369.926
# 8     VEA              Vanguard FTSE Developed Markets ETF   47.94  2.481.278
# 9     ELV                                  Elevance Health  471.45     70.881
# 10    ELV                                  Elevance Health  471.45     70.881
# 11    BND                   Vanguard Total Bond Market ETF   73.64  2.463.036
# 12    BND                   Vanguard Total Bond Market ETF   73.64  2.463.036
# 13   MUFG                           Mitsubishi Ufj Finl Gr    8.59    487.637
# 14   MUFG                           Mitsubishi Ufj Finl Gr    8.59    487.637
#
#    Market Cap DividendYield P/E Ratio FoundYear
# 0       1.8 T                   27.07      2015
# 1       1.7 T                   26.89      2015
# 2     371.8 B         1.45%                2010
# 3     273.5 B         4.00%     42.43      2013
# 4     205.3 B         0.26%     34.92      2006
# 5     182.9 B                   32.85      2015
# 6     128.3 B         1.28%     21.07      2008
# 7     127.6 B                  121.42      2009
# 8     122.8 B         3.15%                2007
# 9     110.8 B         1.26%     18.24      2020
# 10    110.8 B         1.26%     18.24      2020
# 11    104.4 B         3.10%                2007
# 12    104.4 B         3.10%                2007
# 13    103.2 B                    8.15      2005
# 14    103.2 B                    8.15      2005

# %%
best_investment = best_investment.dropna()

best_investment
# Out:
#    Symbol                                             Name   Price     Volume  \
# 0    GOOG                 Alphabet - Class C Capital Stock  140.75  3.162.040
# 1   GOOGL                               Alphabet - Class A  139.65  3.411.497
# 2     VOO                             Vanguard S&P 500 ETF  437.06    810.726
# 3    ABBV                                           Abbvie  155.05    437.883
# 4     TMO                         Thermo Fisher Scientific  532.59    126.537
# 5     PDD        PDD Holdings - American Depositary Shares  145.95  1.068.642
# 6     BUD  Anheuser-Busch Inbev SA Sponsored ADR (Belgium)   64.66    220.747
# 7    UBER                                Uber Technologies   62.00  5.369.926
# 8     VEA              Vanguard FTSE Developed Markets ETF   47.94  2.481.278
# 9     ELV                                  Elevance Health  471.45     70.881
# 10    ELV                                  Elevance Health  471.45     70.881
# 11    BND                   Vanguard Total Bond Market ETF   73.64  2.463.036
# 12    BND                   Vanguard Total Bond Market ETF   73.64  2.463.036
# 13   MUFG                           Mitsubishi Ufj Finl Gr    8.59    487.637
# 14   MUFG                           Mitsubishi Ufj Finl Gr    8.59    487.637
#
#    Market Cap DividendYield P/E Ratio FoundYear
# 0       1.8 T                   27.07      2015
# 1       1.7 T                   26.89      2015
# 2     371.8 B         1.45%                2010
# 3     273.5 B         4.00%     42.43      2013
# 4     205.3 B         0.26%     34.92      2006
# 5     182.9 B                   32.85      2015
# 6     128.3 B         1.28%     21.07      2008
# 7     127.6 B                  121.42      2009
# 8     122.8 B         3.15%                2007
# 9     110.8 B         1.26%     18.24      2020
# 10    110.8 B         1.26%     18.24      2020
# 11    104.4 B         3.10%                2007
# 12    104.4 B         3.10%                2007
# 13    103.2 B                    8.15      2005
# 14    103.2 B                    8.15      2005

# %%
best_investment = best_investment.drop_duplicates()

best_investment
# Out:
#    Symbol                                             Name   Price     Volume  \
# 0    GOOG                 Alphabet - Class C Capital Stock  140.75  3.162.040
# 1   GOOGL                               Alphabet - Class A  139.65  3.411.497
# 2     VOO                             Vanguard S&P 500 ETF  437.06    810.726
# 3    ABBV                                           Abbvie  155.05    437.883
# 4     TMO                         Thermo Fisher Scientific  532.59    126.537
# 5     PDD        PDD Holdings - American Depositary Shares  145.95  1.068.642
# 6     BUD  Anheuser-Busch Inbev SA Sponsored ADR (Belgium)   64.66    220.747
# 7    UBER                                Uber Technologies   62.00  5.369.926
# 8     VEA              Vanguard FTSE Developed Markets ETF   47.94  2.481.278
# 9     ELV                                  Elevance Health  471.45     70.881
# 11    BND                   Vanguard Total Bond Market ETF   73.64  2.463.036
# 13   MUFG                           Mitsubishi Ufj Finl Gr    8.59    487.637
#
#    Market Cap DividendYield P/E Ratio FoundYear
# 0       1.8 T                   27.07      2015
# 1       1.7 T                   26.89      2015
# 2     371.8 B         1.45%                2010
# 3     273.5 B         4.00%     42.43      2013
# 4     205.3 B         0.26%     34.92      2006
# 5     182.9 B                   32.85      2015
# 6     128.3 B         1.28%     21.07      2008
# 7     127.6 B                  121.42      2009
# 8     122.8 B         3.15%                2007
# 9     110.8 B         1.26%     18.24      2020
# 11    104.4 B         3.10%                2007
# 13    103.2 B                    8.15      2005

# %%
import numpy as np

best_investment.replace('', np.nan, inplace=True)

best_stocks = best_investment.dropna()

best_stocks
# Out:
# C:\Users\sjroo\AppData\Local\Temp\ipykernel_14100\2239098830.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_investment.replace('', np.nan, inplace=True)
#   Symbol                                             Name   Price   Volume  \
# 3   ABBV                                           Abbvie  155.05  437.883
# 4    TMO                         Thermo Fisher Scientific  532.59  126.537
# 6    BUD  Anheuser-Busch Inbev SA Sponsored ADR (Belgium)   64.66  220.747
# 9    ELV                                  Elevance Health  471.45   70.881
#
#   Market Cap DividendYield P/E Ratio FoundYear
# 3    273.5 B         4.00%     42.43      2013
# 4    205.3 B         0.26%     34.92      2006
# 6    128.3 B         1.28%     21.07      2008
# 9    110.8 B         1.26%     18.24      2020

# %%
import matplotlib.pyplot as plt

best_stocks['DividendYield'] = best_stocks['DividendYield'].str.replace('%', '').astype(float) / 100

best_dividendyield = best_stocks.sort_values(by='DividendYield', ascending=True)

plt.figure(figsize=(10, 6))  
plt.bar(best_stocks['Symbol'], best_dividendyield['DividendYield'], color='skyblue')
plt.xlabel('Company')
plt.ylabel('Dividend Yield')
plt.title('Dividend Yield vs Companies')
plt.xticks(rotation=45)  
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\sjroo\AppData\Local\Temp\ipykernel_14100\2783248362.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_stocks['DividendYield'] = best_stocks['DividendYield'].str.replace('%', '').astype(float) / 100

# %%
best_price = best_stocks.sort_values(by='Price', ascending=False)

plt.figure(figsize=(8, 6))
for label, x, y in zip(best_stocks['Symbol'], best_price['Price'], best_stocks['DividendYield']):
    plt.scatter(x, y, label=label, s=90) 

plt.plot(best_price['Price'].values, best_stocks['DividendYield'].values, linestyle='--', color='orange', label='Línea')
plt.xlabel('Price')
plt.ylabel('DividendYield')
plt.title('Price vs Dividend Yield')
plt.grid(True)

plt.legend()
plt.show()

# %%
correlation = best_stocks['DividendYield'].corr(best_stocks['Price'])

print(f"Correlación entre 'DividendYield' y 'Price': {correlation}")
# Out:
# Correlación entre 'DividendYield' y 'Price': -0.5802176488011358

# %%
best_peratio = best_stocks.sort_values(by='P/E Ratio', ascending=False)

plt.figure(figsize=(10, 6)) 
plt.bar(best_stocks['Symbol'], best_peratio['P/E Ratio'], color='skyblue')
plt.xlabel('Company')
plt.ylabel('P/E ratio')
plt.title('P/E ratio vs Companies')
plt.xticks(rotation=45) 
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8, 6))
for label, x, y in zip(best_stocks['Symbol'], best_price['Price'], best_peratio['P/E Ratio']):
    plt.scatter(x, y, label=label, s=90) 

plt.title('P/E Ratio vs Price')
plt.ylabel('P/E Ratio')
plt.xlabel('Price')
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.show()

# %%
best_stocks['Price'] = pd.to_numeric(best_stocks['Price'], errors='coerce')
best_stocks['P/E Ratio'] = pd.to_numeric(best_stocks['P/E Ratio'], errors='coerce')
mean_price = best_stocks['Price'].mean()
mean_pe_ratio = best_stocks['P/E Ratio'].mean()

best_stocks['Distance'] = np.sqrt((best_stocks['Price'] - mean_price)**2 + (best_stocks['P/E Ratio'] - mean_pe_ratio)**2)

most_distant_company = best_stocks.loc[best_stocks['Distance'].idxmax()]

print("Empresa más lejana de la media:")
most_distant_company
# Out:
# Empresa más lejana de la media:
# C:\Users\sjroo\AppData\Local\Temp\ipykernel_14100\2526646597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_stocks['Price'] = pd.to_numeric(best_stocks['Price'], errors='coerce')
# C:\Users\sjroo\AppData\Local\Temp\ipykernel_14100\2526646597.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_stocks['P/E Ratio'] = pd.to_numeric(best_stocks['P/E Ratio'], errors='coerce')
# C:\Users\sjroo\AppData\Local\Temp\ipykernel_14100\2526646597.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_stocks['Distance'] = np.sqrt((best_stocks['Price'] - mean_price)**2 + (best_stocks['P/E Ratio'] - mean_pe_ratio)**2)
# Symbol                                                       BUD
# Name             Anheuser-Busch Inbev SA Sponsored ADR (Belgium)
# Price                                                      64.66
# Volume                                                   220.747
# Market Cap                                               128.3 B
# DividendYield                                             0.0128
# P/E Ratio                                                  21.07
# FoundYear                                                   2008
# Distance                                              241.413258
# Name: 6, dtype: object

# %%
correlation = best_stocks['P/E Ratio'].corr(best_stocks['Price'])

print(f"Correlación entre 'P/E Ratio' y 'Price': {correlation}")
# Out:
# Correlación entre 'P/E Ratio' y 'Price': -0.06960915698298187

# %%
plt.figure(figsize=(8, 6))

plt.figure(figsize=(8, 6))
for label, x, y in zip(best_stocks['Symbol'], best_dividendyield['DividendYield'], best_peratio['P/E Ratio']):
    plt.scatter(x, y, label=label, s=90) 

plt.title('P/E Ratio vs Divicend Yield')
plt.ylabel('P/E Ratio')
plt.xlabel('Dividend Yield')
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.show()

# %%
correlation = best_stocks['P/E Ratio'].corr(best_stocks['DividendYield'])

print(f"Correlación entre 'P/E Ratio' y 'Dividend Yield': {correlation}")
# Out:
# Correlación entre 'P/E Ratio' y 'Dividend Yield': 0.5512783241385004
